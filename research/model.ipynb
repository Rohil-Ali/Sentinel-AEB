# %% [markdown]
# # Model Testing

# %%
from ultralytics import YOLO

model = YOLO('yolov8s.pt')  # loads pre trained model on coco

# %% [markdown]
# ## Baseline testing

# %%
metrics = model.val(data='dataset/data.yaml', device=0)

print(f"mAP50-95: {metrics.box.map}") 
print(f"mAP50: {metrics.box.map50}")
# Out:
# Ultralytics 8.4.8  Python-3.12.10 torch-2.9.1+cu126 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# YOLOv8s summary (fused): 72 layers, 11,156,544 parameters, 0 gradients, 28.6 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 123.640.5 MB/s, size: 50.5 KB)
# val: Scanning C:\Users\Rohil\Desktop\Final Year Project\Sentinel-AEB\research\dataset\valid\labels.cache... 2017 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2017/2017  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 127/127 6.1it/s 20.8s0.2s
#                    all       2017      37825     0.0198     0.0655     0.0149    0.00948
#                 person       1649       7159    0.00202     0.0253    0.00108   0.000408
#                bicycle       1134       5500          0          0          0          0
#                    car          5          6   1.12e-05      0.333   2.43e-05   1.64e-05
# ...

# %% [markdown]
# ## Retrain model

# %%
#Train on BDD100K
model.train(
    data='dataset/data.yaml', 
    epochs=35,
    patience=10, 
    imgsz=640, 
    batch=16,
    freeze=0,
    workers=2,
    name='yolov8s_bdd_finetune'
)
# Out:
# Ultralytics 8.4.8  Python-3.12.10 torch-2.9.1+cu126 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...
